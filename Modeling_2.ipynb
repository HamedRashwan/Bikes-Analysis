# %%
import pandas as pd
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from datasist.structdata import detect_outliers

# %%
df=pd.read_csv('bikes.csv')
df
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# 0          81.0        NaN       3          13                  16
# 1          80.0     0.0000       8          32                  40
# 2           NaN     0.0000       5          27                  32
# 3          75.0     0.0000       3          10                  13
# 4          75.0        NaN       0           1                   1
# ...         ...        ...     ...         ...                 ...
# 10881      50.0    26.0027       7         329                 336
# 10882       NaN        NaN      10         231                 241
# 10883      61.0    15.0013       4         164                 168
# 10884       NaN     6.0032      12         117                 129
# 10885      66.0     8.9981       4          84                  88
#
# [10886 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  object
#  1   season              10672 non-null  object
#  2   holiday             10030 non-null  float64
#  3   workingday          9388 non-null   float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 935.6+ KB

# %%
df.isnull().sum()
# Out:
# datetime                 0
# season                 214
# holiday                856
# workingday            1498
# weather               2140
# temp                  2782
# humidity              3424
# windspeed             4066
# casual                   0
# registered               0
# rented_bikes_count       0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# datetime              0
# season                0
# holiday               0
# workingday            0
# weather               0
# temp                  0
# humidity              0
# windspeed             0
# casual                0
# registered            0
# rented_bikes_count    0
# dtype: int64

# %%
num_col=df.select_dtypes('number').columns
num_col
# Out:
# Index(['holiday', 'workingday', 'temp', 'humidity', 'windspeed', 'casual',
#        'registered', 'rented_bikes_count'],
#       dtype='object')

# %%
df['datetime']=pd.to_datetime(df['datetime'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2177 entries, 3 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            2177 non-null   datetime64[ns]
#  1   season              2177 non-null   object
#  2   holiday             2177 non-null   float64
#  3   workingday          2177 non-null   float64
#  4   weather             2177 non-null   object
#  5   temp                2177 non-null   float64
#  6   humidity            2177 non-null   float64
#  7   windspeed           2177 non-null   float64
#  8   casual              2177 non-null   int64
#  9   registered          2177 non-null   int64
#  10  rented_bikes_count  2177 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(3), object(2)
# memory usage: 204.1+ KB

# %%
indexes=detect_outliers(df,0,num_col)
len(indexes)
# Out:
# 337

# %%
df.drop(indexes,axis=0,inplace=True)
df
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 14    2011-01-01 14:00:00  Spring      0.0         0.0    Mist  18.86
# 15    2011-01-01 15:00:00  Spring      0.0         0.0    Mist  18.04
# 16    2011-01-01 16:00:00  Spring      0.0         0.0    Mist  17.22
# 26    2011-01-02 02:00:00  Spring      0.0         0.0    Mist  17.22
# ...                   ...     ...      ...         ...     ...    ...
# 10844 2012-12-18 06:00:00  Winter      0.0         1.0   Clear  14.76
# 10848 2012-12-18 10:00:00  Winter      0.0         1.0   Clear  18.04
# 10873 2012-12-19 11:00:00  Winter      0.0         1.0   Clear  16.40
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# 3          75.0     0.0000       3          10                  13
# 14         72.0    19.0012      35          71                 106
# 15         77.0    19.9995      40          70                 110
# 16         82.0    19.9995      41          52                  93
# 26        100.0    19.0012       1           8                   9
# ...         ...        ...     ...         ...                 ...
# 10844      93.0    11.0014       1         117                 118
# 10848      77.0     6.0032      22         162                 184
# 10873      54.0    15.0013      31         169                 200
# 10881      50.0    26.0027       7         329                 336
# 10885      66.0     8.9981       4          84                  88
#
# [1840 rows x 11 columns]

# %%
df['year']=df['datetime'].dt.year
df['month']=df['datetime'].dt.month

# %%
cat_col=df.select_dtypes('object').columns
cat_col
# Out:
# Index(['season', 'weather'], dtype='object')

# %%
df=pd.get_dummies(df,cat_col,drop_first=True)
df
# Out:
#                  datetime  holiday  workingday   temp  humidity  windspeed  \
# 3     2011-01-01 03:00:00      0.0         0.0   9.84      75.0     0.0000
# 14    2011-01-01 14:00:00      0.0         0.0  18.86      72.0    19.0012
# 15    2011-01-01 15:00:00      0.0         0.0  18.04      77.0    19.9995
# 16    2011-01-01 16:00:00      0.0         0.0  17.22      82.0    19.9995
# 26    2011-01-02 02:00:00      0.0         0.0  17.22     100.0    19.0012
# ...                   ...      ...         ...    ...       ...        ...
# 10844 2012-12-18 06:00:00      0.0         1.0  14.76      93.0    11.0014
# 10848 2012-12-18 10:00:00      0.0         1.0  18.04      77.0     6.0032
# 10873 2012-12-19 11:00:00      0.0         1.0  16.40      54.0    15.0013
# 10881 2012-12-19 19:00:00      0.0         1.0  15.58      50.0    26.0027
# 10885 2012-12-19 23:00:00      0.0         1.0  13.12      66.0     8.9981
#
#        casual  registered  rented_bikes_count  year  month  season_Spring  \
# 3           3          10                  13  2011      1           True
# 14         35          71                 106  2011      1           True
# 15         40          70                 110  2011      1           True
# 16         41          52                  93  2011      1           True
# 26          1           8                   9  2011      1           True
# ...       ...         ...                 ...   ...    ...            ...
# 10844       1         117                 118  2012     12          False
# 10848      22         162                 184  2012     12          False
# 10873      31         169                 200  2012     12          False
# 10881       7         329                 336  2012     12          False
# 10885       4          84                  88  2012     12          False
#
#        season_Summer  season_Winter  weather_Mist  weather_Rainy
# 3              False          False         False          False
# 14             False          False          True          False
# 15             False          False          True          False
# 16             False          False          True          False
# 26             False          False          True          False
# ...              ...            ...           ...            ...
# 10844          False           True         False          False
# 10848          False           True         False          False
# 10873          False           True         False          False
# 10881          False           True         False          False
# 10885          False           True         False          False
#
# [1840 rows x 16 columns]

# %%
df.drop('datetime',axis=1,inplace=True)
df
# Out:
#        holiday  workingday   temp  humidity  windspeed  casual  registered  \
# 3          0.0         0.0   9.84      75.0     0.0000       3          10
# 14         0.0         0.0  18.86      72.0    19.0012      35          71
# 15         0.0         0.0  18.04      77.0    19.9995      40          70
# 16         0.0         0.0  17.22      82.0    19.9995      41          52
# 26         0.0         0.0  17.22     100.0    19.0012       1           8
# ...        ...         ...    ...       ...        ...     ...         ...
# 10844      0.0         1.0  14.76      93.0    11.0014       1         117
# 10848      0.0         1.0  18.04      77.0     6.0032      22         162
# 10873      0.0         1.0  16.40      54.0    15.0013      31         169
# 10881      0.0         1.0  15.58      50.0    26.0027       7         329
# 10885      0.0         1.0  13.12      66.0     8.9981       4          84
#
#        rented_bikes_count  year  month  season_Spring  season_Summer  \
# 3                      13  2011      1           True          False
# 14                    106  2011      1           True          False
# 15                    110  2011      1           True          False
# 16                     93  2011      1           True          False
# 26                      9  2011      1           True          False
# ...                   ...   ...    ...            ...            ...
# 10844                 118  2012     12          False          False
# 10848                 184  2012     12          False          False
# 10873                 200  2012     12          False          False
# 10881                 336  2012     12          False          False
# 10885                  88  2012     12          False          False
#
#        season_Winter  weather_Mist  weather_Rainy
# 3              False         False          False
# 14             False          True          False
# 15             False          True          False
# 16             False          True          False
# 26             False          True          False
# ...              ...           ...            ...
# 10844           True         False          False
# 10848           True         False          False
# 10873           True         False          False
# 10881           True         False          False
# 10885           True         False          False
#
# [1840 rows x 15 columns]

# %%
df.corr()
# Out:
#                     holiday  workingday      temp  humidity  windspeed  \
# holiday                 NaN         NaN       NaN       NaN        NaN
# workingday              NaN    1.000000  0.094854 -0.114650   0.032562
# temp                    NaN    0.094854  1.000000 -0.012533  -0.015724
# humidity                NaN   -0.114650 -0.012533  1.000000  -0.315540
# windspeed               NaN    0.032562 -0.015724 -0.315540   1.000000
# casual                  NaN   -0.142112  0.502379 -0.305999   0.104184
# registered              NaN    0.153716  0.259482 -0.243220   0.070151
# rented_bikes_count      NaN    0.102123  0.331634 -0.275474   0.082871
# year                    NaN   -0.012734  0.043601 -0.030709  -0.037907
# month                   NaN   -0.004296  0.260963  0.217994  -0.153992
# season_Spring           NaN   -0.018418 -0.557247 -0.199880   0.129266
# season_Summer           NaN    0.040212  0.169799 -0.002904   0.038972
# season_Winter           NaN   -0.020422 -0.245318  0.143062  -0.086406
# weather_Mist            NaN   -0.010584 -0.036706  0.170684  -0.035059
# weather_Rainy           NaN   -0.022377  0.000544  0.325507   0.014059
#
#                       casual  registered  rented_bikes_count      year  \
# holiday                  NaN         NaN                 NaN       NaN
# workingday         -0.142112    0.153716            0.102123 -0.012734
# temp                0.502379    0.259482            0.331634  0.043601
# humidity           -0.305999   -0.243220           -0.275474 -0.030709
# windspeed           0.104184    0.070151            0.082871 -0.037907
# casual              1.000000    0.566560            0.703310  0.090148
# registered          0.566560    1.000000            0.984250  0.163281
# rented_bikes_count  0.703310    0.984250            1.000000  0.160203
# year                0.090148    0.163281            0.160203  1.000000
# month               0.124788    0.166078            0.170047  0.032608
# season_Spring      -0.256189   -0.165905           -0.198089 -0.005354
# season_Summer       0.081697   -0.014273            0.005214 -0.030562
# season_Winter      -0.083106    0.091266            0.060906  0.042038
# weather_Mist        0.003257   -0.002598           -0.001543  0.068003
# weather_Rainy      -0.103451   -0.103892           -0.111822 -0.004914
#
#                        month  season_Spring  season_Summer  season_Winter  \
# holiday                  NaN            NaN            NaN            NaN
# workingday         -0.004296      -0.018418       0.040212      -0.020422
# temp                0.260963      -0.557247       0.169799      -0.245318
# humidity            0.217994      -0.199880      -0.002904       0.143062
# windspeed          -0.153992       0.129266       0.038972      -0.086406
# casual              0.124788      -0.256189       0.081697      -0.083106
# registered          0.166078      -0.165905      -0.014273       0.091266
# rented_bikes_count  0.170047      -0.198089       0.005214       0.060906
# year                0.032608      -0.005354      -0.030562       0.042038
# month               1.000000      -0.763260      -0.247706       0.766847
# season_Spring      -0.763260       1.000000      -0.321631      -0.357180
# season_Summer      -0.247706      -0.321631       1.000000      -0.339700
# season_Winter       0.766847      -0.357180      -0.339700       1.000000
# weather_Mist        0.017462       0.006390       0.003083       0.048736
# weather_Rainy      -0.010059      -0.014527       0.012149      -0.019171
#
#                     weather_Mist  weather_Rainy
# holiday                      NaN            NaN
# workingday             -0.010584      -0.022377
# temp                   -0.036706       0.000544
# humidity                0.170684       0.325507
# windspeed              -0.035059       0.014059
# casual                  0.003257      -0.103451
# registered             -0.002598      -0.103892
# rented_bikes_count     -0.001543      -0.111822
# year                    0.068003      -0.004914
# month                   0.017462      -0.010059
# season_Spring           0.006390      -0.014527
# season_Summer           0.003083       0.012149
# season_Winter           0.048736      -0.019171
# weather_Mist            1.000000      -0.187179
# weather_Rainy          -0.187179       1.000000

# %%
df.drop('holiday',axis=1,inplace=True)

# %%
df.drop(['casual','registered'],axis=1,inplace=True)
df
# Out:
#        workingday   temp  humidity  windspeed  rented_bikes_count  year  \
# 3             0.0   9.84      75.0     0.0000                  13  2011
# 14            0.0  18.86      72.0    19.0012                 106  2011
# 15            0.0  18.04      77.0    19.9995                 110  2011
# 16            0.0  17.22      82.0    19.9995                  93  2011
# 26            0.0  17.22     100.0    19.0012                   9  2011
# ...           ...    ...       ...        ...                 ...   ...
# 10844         1.0  14.76      93.0    11.0014                 118  2012
# 10848         1.0  18.04      77.0     6.0032                 184  2012
# 10873         1.0  16.40      54.0    15.0013                 200  2012
# 10881         1.0  15.58      50.0    26.0027                 336  2012
# 10885         1.0  13.12      66.0     8.9981                  88  2012
#
#        month  season_Spring  season_Summer  season_Winter  weather_Mist  \
# 3          1           True          False          False         False
# 14         1           True          False          False          True
# 15         1           True          False          False          True
# 16         1           True          False          False          True
# 26         1           True          False          False          True
# ...      ...            ...            ...            ...           ...
# 10844     12          False          False           True         False
# 10848     12          False          False           True         False
# 10873     12          False          False           True         False
# 10881     12          False          False           True         False
# 10885     12          False          False           True         False
#
#        weather_Rainy
# 3              False
# 14             False
# 15             False
# 16             False
# 26             False
# ...              ...
# 10844          False
# 10848          False
# 10873          False
# 10881          False
# 10885          False
#
# [1840 rows x 12 columns]

# %%
x=df.drop('rented_bikes_count',axis=1)
y=df['rented_bikes_count']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
models={
    'LR':LinearRegression(),
    'KNN':KNeighborsRegressor(n_neighbors=7),
    'SVR':SVR()
}

# %%
for name,model in models.items():
    print('using:',name)
    model.fit(x_train,y_train)
    print('train accuracy: ',model.score(x_train,y_train))
    print('test accuracy: ',model.score(x_test,y_test))
    print('-'*20)
# Out:
# using: LR
# train accuracy:  0.24913257296251579
# test accuracy:  0.19544808052899132
# --------------------
# using: KNN
# train accuracy:  0.3738649399846389
# test accuracy:  0.10636506511114285
# --------------------
# using: SVR
# train accuracy:  -0.046884338941015624
# test accuracy:  -0.06390851158378186
# --------------------
